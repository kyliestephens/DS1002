# %% [markdown]
# <a href="https://colab.research.google.com/github/kyliestephens/DS1002/blob/main/Assignments/07_More_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # More pandas exercises
#
# Create a Colab notebook. Complete the tasks as specified in the directions. Run each cell to return the desired output. Save your notebook back to your GitHub repository and submit the GitHub URL for your notebook for review.

# %% [markdown]
# 1.  Load the following dataset into Colab and perform the requested operations in code.
#
#  Source: https://ds1002-resources.s3.amazonaws.com/data/ride_sharing.csv

# %%
#loading pandas and the data"
import pandas as pd
import numpy as np
rides = pd.read_csv('https://ds1002-resources.s3.amazonaws.com/data/ride_sharing.csv')

# %%
# show how many rows and columns are in this dataset
rows, columns = rides.shape
print("The number of rows is:", rows)
print("The number of columns is:", columns)
# Out:
# The number of rows is: 25760
# The number of columns is: 10

# %%
#This was to allow me to see the data frame before I began my tasks.
rides
# Out:
#          duration  station_A_id  \
# 0      12 minutes            81
# 1      24 minutes             3
# 2       8 minutes            67
# 3       4 minutes            16
# 4      11 minutes            22
# ...           ...           ...
# 25755  11 minutes            15
# 25756  10 minutes            15
# 25757  14 minutes            15
# 25758  14 minutes            15
# 25759  29 minutes            16
#
#                                           station_A_name  station_B_id  \
# 0                                     Berry St at 4th St           323
# 1           Powell St BART Station (Market St at 4th St)           118
# 2      San Francisco Caltrain Station 2  (Townsend St...            23
# 3                                Steuart St at Market St            28
# 4                                  Howard St at Beale St           350
# ...                                                  ...           ...
# 25755  San Francisco Ferry Building (Harry Bridges Pl...            34
# 25756  San Francisco Ferry Building (Harry Bridges Pl...            34
# 25757  San Francisco Ferry Building (Harry Bridges Pl...            42
# 25758  San Francisco Ferry Building (Harry Bridges Pl...            42
# 25759                            Steuart St at Market St           115
#
#                                       station_B_name  bike_id  user_type  \
# 0                                 Broadway at Kearny     5480          2
# 1                    Eureka Valley Recreation Center     5193          2
# 2                      The Embarcadero at Steuart St     3652          3
# 3                       The Embarcadero at Bryant St     1883          1
# 4                               8th St at Brannan St     4626          2
# ...                                              ...      ...        ...
# 25755                 Father Alfred E Boeddeker Park     5063          1
# 25756                 Father Alfred E Boeddeker Park     5411          2
# 25757  San Francisco City Hall (Polk St at Grove St)     5157          2
# 25758  San Francisco City Hall (Polk St at Grove St)     4438          2
# 25759                             Jackson Playground     1705          3
#
#        user_birth_year user_gender  tire_size
# 0                 1959        Male         26
# 1                 1965        Male         27
# 2                 1993        Male         29
# 3                 1979        Male         26
# 4                 1994        Male         27
# ...                ...         ...        ...
# 25755             2000        Male         26
# 25756             1998        Male         26
# 25757             1995        Male         26
# 25758             1995        Male         27
# 25759             1990        Male         27
#
# [25760 rows x 10 columns]

# %%
# The first column, "duration" is seen as a string.
# Using two snippets of code, clean this column up so that
# is now an integer (int64)
rides['duration'] = rides['duration'].str.strip('minutes')
#This code stripped the word minutes from the data in duration column, which allowed me to convert it to an integer
rides['duration'] = rides['duration'].astype('int')

# %%
# Now display the datatypes in the updated dataframe
rides.dtypes
#As you can see below, the data type for duration is now an integer, indicated by int64
# Out:
# duration            int64
# station_A_id        int64
# station_A_name     object
# station_B_id        int64
# station_B_name     object
# bike_id             int64
# user_type           int64
# user_birth_year     int64
# user_gender        object
# tire_size           int64
# dtype: object

# %%
# Show the min and max values of ride durations (the shortest and longest rides)
# Hint: If 'df' is the name of your dataframe, simply specify the column name
# and then append the .min() or .max() methods.
longestride = rides['duration'].max()
shortestride = rides['duration'].min()

print("The longest car ride is:", longestride, "minutes long")
print("The shortest car ride is:", shortestride, "minutes long")
# Out:
# The longest car ride is: 1372 minutes long
# The shortest car ride is: 1 minutes long

# %%
# Create a new dataframe object and populate it with rides that are 60 minutes or less.
# Hint: Use the .query() method for the dataframe that we used in class.
newdataset = rides.query('duration <= 60')
#this code creates a new data set with ride durations less than or equal to 60 minutes indicated by <=

# %%
# Now show both the min and max values of the duration column for your new dataset.
newlongestride = newdataset['duration'].max()
newshortestride = newdataset['duration'].min()

print("The longest car ride is:", newlongestride, "minutes long")
print("The shortest car ride is:", newshortestride, "minutes long")
#This code follows the same path as before but uses data from newdataset for its answers
# Out:
# The longest car ride is: 60 minutes long
# The shortest car ride is: 1 minutes long

# %%
# Using the new dataframe, update it so that is ONLY has records where
# the tire_size is 26.
updateddataset = newdataset.query('tire_size == 26')

# %%
# Count the number of records with FEMALE rider
# Finally, produce a count of all records with FEMALE riders
# using the 26-inch wheeled rental bikes for their rentals of
# one hour or less.
finalfilter = updateddataset.query('user_gender == "FEMALE"')
count = len(finalfilter) #This gives a count of the female riders in the updateddataset using the length function
#This works because updateddataset contains only rides with 26 inch tires and durations of 60 min or less
print("The number of records of female riders using 26 inch wheeled rental bikes for their rentals of one hour or less is:", count)
# Out:
# The number of records of female riders using 26 inch wheeled rental bikes for their rentals of one hour or less is: 0

# %% [markdown]
# 2. Find the file `more-messy-data.csv` on Canvas and upload it into Google Colab.
#
# Create a new Pandas DataFrame from that data and perform the following steps.

# %%
#This code loads the data from the file provided on Github- did this by clicking the raw button to get the proper csv link
rides2 = pd.read_csv("https://raw.githubusercontent.com/aaron-abrams-uva/DS1002-S24/main/data/more-messy-data.csv")
# Write a snippet of code that will display the number of duplicate rows exist in the DF.
rides2.duplicated()
print(rides2.duplicated().sum())
# Out:
# 287

# %%
# Next, remove all duplicate rows using Python.
rides2 = rides2.drop_duplicates()

# %%
# For the FOUR columns involving sepal and petal length and width, update all NaN
# values with the column mean.
means = rides2[columns].mean(numeric_only=True)
#the numeric_only ensures that this code will work in future pandas; without numeric_only, a warning was issued.
# Fill NaN values with column means
rides2_means = rides2.fillna(means)
rides2_means #Display new data frame.
# Out:
#        id  sepal_length  sepal_width  petal_length petal_width     species
# 0       1      3.500000      2.90000           1.4         0.5   virginica
# 1       2      3.600000      3.20000           3.0         0.5      setosa
# 2       3      3.800000      2.98876           2.2         1.5      setosa
# 3       4      5.800000      2.70000           2.6         1.2   virginica
# 4       5      4.900000      3.60000           3.0         1.2   virginica
# ...   ...           ...          ...           ...         ...         ...
# 1311  412      4.522004      3.60000           2.9         0.5  Versicolor
# 1312  413      5.800000      2.70000           2.0         0.1  Versicolor
# 1313  414      3.300000      3.70000           1.3         2.8  Versicolor
# 1314  415      3.100000      2.98876           1.1         NaN  Versicolor
# 1315  416      4.300000      2.50000           1.3           1  Versicolor
#
# [1029 rows x 6 columns]

# %%
# Find any values in the dataframe that are still missing, and delete them.
rides2_updated2 = rides2_means.dropna()
rides2_updated2
# Out:
#        id  sepal_length  sepal_width  petal_length petal_width     species
# 0       1      3.500000      2.90000           1.4         0.5   virginica
# 1       2      3.600000      3.20000           3.0         0.5      setosa
# 2       3      3.800000      2.98876           2.2         1.5      setosa
# 3       4      5.800000      2.70000           2.6         1.2   virginica
# 4       5      4.900000      3.60000           3.0         1.2   virginica
# ...   ...           ...          ...           ...         ...         ...
# 1310  411      4.800000      2.60000           1.9         0.9  Versicolor
# 1311  412      4.522004      3.60000           2.9         0.5  Versicolor
# 1312  413      5.800000      2.70000           2.0         0.1  Versicolor
# 1313  414      3.300000      3.70000           1.3         2.8  Versicolor
# 1315  416      4.300000      2.50000           1.3           1  Versicolor
#
# [887 rows x 6 columns]

# %%
# How many different species are there?
species_count = rides2_updated2['species'].nunique()
print("The number of different species in this data frame is:", species_count)
# Out:
# The number of different species in this data frame is: 9

# %%
#This code allowed me to see what I needed to change for cleaning up the species variable.
species_counts = rides2_updated2['species'].value_counts()
species_number = len(species_counts)
#Counts the spcies using value counts function and length function
species_names = species_counts.index.tolist()
#By converting the index species_counts to a list, I am able to see the specific changes I need to make to the names.
species_names
# Out:
# ['setosa',
#  'virginica',
#  'Versicolor',
#  'setoso',
#  'Virginia',
#  'Viginica',
#  'Setosa',
#  'Setosan',
#  'versicolor']

# %%
# Clean up the 'species' variable so that there are exactly three different values.
#This creates a dictionary to replace mispellings of the three species with the proper species name.
#I know the changes I need to make because of the list of species names above.
rides2_updated2.loc[:, 'species'] = rides2_updated2['species'].replace({
    'setoso': 'setosa',
    'Setosa': 'setosa',
    'Setosan': 'setosa',
    'Virginia': 'virginica',
    'Viginica': 'virginica',
    'Versicolor': 'versicolor'
})
rides2_updated2
#important to include .loc function to tell Python that the code is modifying the original data frame
# Out:
# <ipython-input-68-7fde1cb4f053>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rides2_updated2.loc[:, 'species'] = rides2_updated2['species'].replace({
#        id  sepal_length  sepal_width  petal_length petal_width     species
# 0       1      3.500000      2.90000           1.4         0.5   virginica
# 1       2      3.600000      3.20000           3.0         0.5      setosa
# 2       3      3.800000      2.98876           2.2         1.5      setosa
# 3       4      5.800000      2.70000           2.6         1.2   virginica
# 4       5      4.900000      3.60000           3.0         1.2   virginica
# ...   ...           ...          ...           ...         ...         ...
# 1310  411      4.800000      2.60000           1.9         0.9  versicolor
# 1311  412      4.522004      3.60000           2.9         0.5  versicolor
# 1312  413      5.800000      2.70000           2.0         0.1  versicolor
# 1313  414      3.300000      3.70000           1.3         2.8  versicolor
# 1315  416      4.300000      2.50000           1.3           1  versicolor
#
# [887 rows x 6 columns]

# %%
#To confirm the above code worked:
species_count2 = rides2_updated2['species'].nunique()
print("The number of different species in this data frame is:", species_count2)
# Out:
# The number of different species in this data frame is: 3

# %% [markdown]
# 3. Bonus:  Regular expressions
#
# Ordinary (non-vanity) Virginia license plates have the form `ABC1234`, meaning they have three upper case letters followed by four digits.  Write a regular expression that matches any string of this form (and doesn't match anything else).  Test your expression with code to make sure it works.
#
# To figure out out how to do this, start with the sample code below.  The `re` package has various functions related to regular expressions, including for example `match()`, which takes two arguments, first the regular expression and second the test string, and tests to see whether the *beginning* of the `test` string matches the pattern `exp`.
#
# Note that `re.match(exp,test)` does not return a boolean variable, as you might expect (in other words, a match doesn't return `True` and a non-match `False`).  The type of object you get is called `re.Match`, which is a data type special to the `re` package.  (The reason for this is that the object contains more information than just whether there is a match or not.) However, you can turn it into a boolean using `bool()` if you want.
#
# Include the following in the notebook you submit:
#
#  1. A regular expression in a text chunk
#  2. One or more code chunks in which you test several strings to verify that your regex is correct.
#  3. Make sure you display the results of testing various strings.
#
#  See this [documentation page](https://docs.python.org/3/howto/regex.html#regex-howto) for further help.

# %%
# Sample code for testing whether a string matches a regex

# First import this package for working with regular expressions
import re

# Here is an example.
# Play around with different expressions and test strings to see what happens.
exp = 'ab+'
test = 'aabbbc'

if re.match(exp,test):
  print("match!")
else:
  print("no match")

# uncomment this line if you want
# print(type(re.match(exp,test)))

# uncomment this line if you want
# print(bool(re.match(exp,test)))
